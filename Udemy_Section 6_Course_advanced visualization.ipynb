# %% [markdown]
# ### section recap
# 1. Category data type in Python
# 2. Jointplots
# 3. Histograms
# 4. Stacked Histograms
# 5. KDE plot
# 6. Using the subplots() function
# 7. Violinplots
# 8. Creating a Facet Grid
# 9. Cooirdiantes and Diagonais
# 10. Building Dashboards
# 11. Styling Tips
# 12. Tiltles and Labels

# %%
import pandas as pd

# %%
movies = pd.read_csv('/Users/vitamind/Downloads/python_udemy/P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns =['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
#makes no sense to Year
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %% [markdown]
# ### turn the integers into the categories

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
#now Film is considered as a category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
#同理，改变 year 的类别
movies.Year = movies.Year.astype('category')
movies.Genre = movies.Genre.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
#想要知道一个 category 中有哪些 categories 呢？
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe() 
#没有 years 了
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Jointplot

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')
# 展示了x与y 的相关性；也展示了描述性数据

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind="reg")

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind="resid")

# %%
#change the style 
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind="kde")

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind="hex")
# see the clusters

# %% [markdown]
# ### histogram

# %%
#already know this method:
#改变背景
sns.set_style("darkgrid")
ml = sns.distplot(movies.AudienceRating, bins=15,)

# %%
#with plt.hist
nl = plt.hist(movies.CriticRating, bins=15)

# %%
#改变背景
sns.set_style("darkgrid")
nl = plt.hist(movies.AudienceRating, bins=20)

# %% [markdown]
# #### creating stacked Histogram

# %%
#filter the genre --> 该类型所对应的 budgetmillions 所属 column
movies[movies.Genre =='Drama'].BudgetMillions
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
#画出对应的图像，将 column 代入
h2 = plt.hist(movies[movies.Genre =='Drama'].BudgetMillions)

# %%
plt.hist(movies[movies.Genre =='Drama'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre =='Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre =='Thriller'].BudgetMillions,bins=15)
plt.show()
#重合出现，改成统一 bins

# %%
#不要遮挡： 制成 list 放入
plt.hist([movies[movies.Genre =='Drama'].BudgetMillions, 
          movies[movies.Genre =='Action'].BudgetMillions],
        bins = 15,stacked = True)
plt.show()

# %% [markdown]
# ### 如果要重合很多组数据怎么办？除了复制粘贴，可以使用 loops 来制作 list

# %%
#如果要重合很多组数据怎么办？除了复制粘贴，可以使用 loops 
# we need change the genre 
for gen in movies.Genre.cat.categories: #此前已经create a category of genre
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)

# %%
# 如何制作图例呢？ 同样使用 loops
mylabels=list()
for gen in movies.Genre.cat.categories:
    mylabels.append(gen)    
print(gen)
# Out:
# Thriller

# %%
sns.set_style("white")
h = plt.hist(list1,bins=30,stacked=True,rwidth=10,label=mylabels)
plt.legend(frameon=True,fancybox=True,shadow=True,framealpha=1,prop={'size':10})
plt.title("Movies Budget Distribution", fontsize=25,\
         color="Blue",fontname="Console")
plt.ylabel("Number of Movies", fontsize=25,color="Red")
plt.xlabel("Budget",fontsize=25,color="Green")
plt.show()

# %%
#KDE Plot

# %%
visl = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',fit_reg=False,hue='Genre',size=7,aspect=1)

# %%
kl = sns.kdeplot(movies.CriticRating, movies.AudienceRating,shade=True,shade_lowest=False,cmap='Reds')

# %% [markdown]
#  ### working with Subplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
kl = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
f, ax = plt.subplots(1,2,figsize=(12,6))
kl = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
sns.violinplot(data=movies, x='Genre',y='CriticRating')

# %%
#creating a facet grid

# %%
g = sns.FacetGrid(movies, row='Genre',hue='Genre')

# %%
#g = g.map()
# plt.scatter(movies.CriticRating, movies.AudienceRating)
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
g = g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
#can populate with any type of chart. Example: histograms
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
g = g.map(plt.hist,'CriticRating')

# %%
#keyword arguments: 
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %%
#controlling axes and adding diagonals:
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c='gray',ls="--")

# %% [markdown]
# ### working with Dashboard

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#加上ax=axes[1,0]
sns.set_style("darkgrid")
f,axes=plt.subplots(2,2,figsize=(15,15))
kl = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating,ax=axes[0,1])
kl.set(xlim=(-20,160))
k3 = sns.violinplot(data=movies, x='Genre',y='CriticRating',ax=axes[1,0])
k4 = sns.kdeplot(movies.CriticRating, movies.AudienceRating,shade=True,shade_lowest=False,cmap='Reds')
